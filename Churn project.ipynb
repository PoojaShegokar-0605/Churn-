# %%
#Importing the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel(r"C:\Users\pooja\Desktop\chrun dataset_3333.xlsx")

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    WI             114        415                 No             Yes
# 3329    AL             106        408                 No             Yes
# 3330    VT              60        415                 No              No
# 3331    WV             159        415                 No              No
# 3332    CT             184        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     26              137.1               88
# 3329                     29               83.6              131
# 3330                      0              193.9              118
# 3331                      0              169.8              114
# 3332                      0              213.8              105
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
data.shapePreview
# Out:
# (3333, 20)

# %%
data.nunique()
# Out:
# State                       51
# Account length             212
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       46
# Total day minutes         1667
# Total day calls            119
# Total day charge          1667
# Total eve minutes         1611
# Total eve calls            123
# Total eve charge          1440
# Total night minutes       1591
# Total night calls          120
# Total night charge         933
# Total intl minutes         162
# Total intl calls            21
# Total intl charge          162
# Customer service calls      10
# Churn                        2
# dtype: int64

# %%
data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
data.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
data.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
data.describe(include='object')
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
data.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
data.isna().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
data.notna().sum()
# Out:
# State                     3333
# Account length            3333
# Area code                 3333
# International plan        3333
# Voice mail plan           3333
# Number vmail messages     3333
# Total day minutes         3333
# Total day calls           3333
# Total day charge          3333
# Total eve minutes         3333
# Total eve calls           3333
# Total eve charge          3333
# Total night minutes       3333
# Total night calls         3333
# Total night charge        3333
# Total intl minutes        3333
# Total intl calls          3333
# Total intl charge         3333
# Customer service calls    3333
# Churn                     3333
# dtype: int64

# %%
data.notnull().sum()
# Out:
# State                     3333
# Account length            3333
# Area code                 3333
# International plan        3333
# Voice mail plan           3333
# Number vmail messages     3333
# Total day minutes         3333
# Total day calls           3333
# Total day charge          3333
# Total eve minutes         3333
# Total eve calls           3333
# Total eve charge          3333
# Total night minutes       3333
# Total night calls         3333
# Total night charge        3333
# Total intl minutes        3333
# Total intl calls          3333
# Total intl charge         3333
# Customer service calls    3333
# Churn                     3333
# dtype: int64

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [State, Account length, Area code, International plan, Voice mail plan, Number vmail messages, Total day minutes, Total day calls, Total day charge, Total eve minutes, Total eve calls, Total eve charge, Total night minutes, Total night calls, Total night charge, Total intl minutes, Total intl calls, Total intl charge, Customer service calls, Churn]
# Index: []

# %%
data.drop_duplicates()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    WI             114        415                 No             Yes
# 3329    AL             106        408                 No             Yes
# 3330    VT              60        415                 No              No
# 3331    WV             159        415                 No              No
# 3332    CT             184        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# # 1. Analysing the 'Churn' Variable

# %%
data['Churn'].unique()
# Out:
# array([False,  True])

# %%
data['Churn'].nunique()
# Out:
# 2

# %%
A= data['Churn'].value_counts()
print(A)
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
str(483*100/3333)+'%'
# Out:
# '14.491449144914492%'

# %%
str(2850*100/3333)+'%'
# Out:
# '85.5085508550855%'

# %%
type(A)
# Out:
# pandas.core.series.Series

# %%
A
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
plt.pie(A,labels=['Not Churned', 'Churned'],colors=['orange','red'],startangle=50,radius=2,explode=(0,0.2),shadow=True,
        autopct='%1.2f%%',pctdistance=0.75);
circle=plt.Circle((0,0),1,color='white')
c=plt.gcf()
c.gca().add_artist(circle)
plt.axis('equal')
plt.title('Churned vs Non-Churned')
plt.show()

# %%
plt.pie(A,labels=['NC',"C"],shadow=True,startangle=50,colors=['r','g'],explode=(0,0.2),autopct="%1.2d%%",radius=2,pctdistance=0.60)
plt.pie([1],colors="w",radius=1)
plt.show()

# %%
plt.pie(A,labels=['NC',"C"],shadow=True,startangle=50,colors=['r','g'],explode=(0,0.2),autopct="%1.2d%%",radius=2,pctdistance=0.60)
c=plt.Circle((0,0),1,facecolor="w")
plt.gca().add_artist(c)
plt.show()

# %%
plt.pie([1])
# Out:
# ([<matplotlib.patches.Wedge at 0x19fa67b8310>],
#  [Text(-1.1, 1.3471114790620887e-16, '')])

# %%
plt.pie([1],colors='g')
# Out:
# ([<matplotlib.patches.Wedge at 0x19fa67eddc0>],
#  [Text(-1.1, 1.3471114790620887e-16, '')])

# %%
sns.countplot(data['Churn'])
plt.show()

# %% [markdown]
# # 2. Analysing the 'State' Variable

# %%
data.State.nunique()
# Out:
# 51

# %%
data.State.unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'WV', 'RI', 'IA', 'MT',
#        'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'NE', 'WY', 'IL', 'NH',
#        'LA', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR', 'DE', 'IN', 'UT', 'CA',
#        'SD', 'NC', 'WA', 'MN', 'NM', 'NV', 'DC', 'NY', 'KY', 'ME', 'MS',
#        'MI', 'SC', 'TN', 'PA', 'HI', 'ND', 'CT'], dtype=object)

# %%
data.State.value_counts(ascending=True)
# Out:
# CA     34
# IA     44
# PA     45
# LA     51
# AK     52
# HI     53
# TN     53
# GA     54
# DC     54
# AR     55
# NH     56
# IL     58
# KY     59
# SD     60
# SC     60
# DE     61
# OK     61
# NE     61
# ND     62
# ME     62
# NM     62
# FL     63
# MO     63
# AZ     64
# MS     65
# RI     65
# MA     65
# WA     66
# CO     66
# NV     66
# MT     68
# NJ     68
# NC     68
# KS     70
# MD     70
# IN     71
# TX     72
# UT     72
# VT     73
# MI     73
# ID     73
# CT     74
# WY     77
# VA     77
# OR     78
# WI     78
# OH     78
# AL     80
# NY     83
# MN     84
# WV    106
# Name: State, dtype: int64

# %%
plt.figure(figsize=(20,7))
sns.countplot(data['State'])
plt.xticks(fontsize=7)
plt.yticks(fontsize=7)
plt.xlabel('States',fontsize=20,color='Red')
plt.ylabel('Count',fontsize=20,color='Red')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.countplot(data.State,hue=data.Churn)
sns.set(style='whitegrid')
plt.xlabel('State',fontsize=18,color='green')
plt.ylabel('Count',fontsize=18,color='Orange')
plt.show()

# %%
a=data.groupby("State")['Churn'].mean()*100
print(a.sort_values(ascending=False))
print(a.count())
# Out:
# State
# NJ    26.470588
# CA    26.470588
# TX    25.000000
# MD    24.285714
# SC    23.333333
# MI    21.917808
# MS    21.538462
# NV    21.212121
# WA    21.212121
# ME    20.967742
# MT    20.588235
# AR    20.000000
# KS    18.571429
# NY    18.072289
# MN    17.857143
# PA    17.777778
# MA    16.923077
# CT    16.216216
# NC    16.176471
# NH    16.071429
# GA    14.814815
# DE    14.754098
# OK    14.754098
# OR    14.102564
# UT    13.888889
# CO    13.636364
# KY    13.559322
# SD    13.333333
# OH    12.820513
# FL    12.698413
# IN    12.676056
# ID    12.328767
# WY    11.688312
# MO    11.111111
# VT    10.958904
# AL    10.000000
# NM     9.677419
# ND     9.677419
# WV     9.433962
# TN     9.433962
# DC     9.259259
# RI     9.230769
# WI     8.974359
# IL     8.620690
# NE     8.196721
# LA     7.843137
# IA     6.818182
# VA     6.493506
# AZ     6.250000
# AK     5.769231
# HI     5.660377
# Name: Churn, dtype: float64
# 51

# %%
x=data.State.unique()
y=data.groupby('State')['Churn'].mean().sort_values(ascending=False)*100
sns.set(style='darkgrid')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.plot(x,y,color='black',marker='*',markersize=10)
plt.title('State Chrun Graph',fontsize=25)
plt.xlabel('State',fontsize=30)
plt.ylabel('Churn Rate',fontsize=30)
plt.show()

# %%
x=data.State.unique()
y=data.groupby('State')['Churn'].mean()*100
sns.set(style='darkgrid')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.rcParams['figure.figsize']=(20,7)
plt.rcParams['lines.linestyle']='-'
plt.plot(x,y,color='black',marker='*',markersize=10)
plt.title('State Chrun Graph',fontsize=25)
plt.xlabel('State',fontsize=30)
plt.ylabel('Churn Rate',fontsize=30)
plt.show()

# %%
result = data.groupby('State')['Churn'].mean().sort_values(ascending=False).head(5).reset_index(name='ChurnRate')
result['ChurnRate'] = result['ChurnRate'] * 100
result
# Out:
#   State  ChurnRate
# 0    NJ  26.470588
# 1    CA  26.470588
# 2    TX  25.000000
# 3    MD  24.285714
# 4    SC  23.333333

# %%
data.groupby('State')['Churn'].mean().sort_values(ascending=False).head(5).reset_index(name='ChurnRate') * 100

# %%
data.groupby('State')['Churn'].mean().sort_values(ascending=False).head(5)*100  #top 5 state where churining is more
# Out:
# State
# NJ    26.470588
# CA    26.470588
# TX    25.000000
# MD    24.285714
# SC    23.333333
# Name: Churn, dtype: float64

# %%
c=pd.crosstab(data.State,data.Churn,margins=True)
c['Percentage_churn']=(c[True]*100)/c['All']
print(c.head(5))
print(type(c))
# Out:
# Churn  False  True  All  Percentage_churn
# State
# AK        49     3   52          5.769231
# AL        72     8   80         10.000000
# AR        44    11   55         20.000000
# AZ        60     4   64          6.250000
# CA        25     9   34         26.470588
# <class 'pandas.core.frame.DataFrame'>

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, AK to All
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   False             52 non-null     int64
#  1   True              52 non-null     int64
#  2   All               52 non-null     int64
#  3   Percentage_churn  52 non-null     float64
# dtypes: float64(1), int64(3)
# memory usage: 2.0+ KB

# %%
c.sort_values(by='Percentage_churn',ascending=False).head()
# Out:
# Churn  False  True  All  Percentage_churn
# State
# CA        25     9   34         26.470588
# NJ        50    18   68         26.470588
# TX        54    18   72         25.000000
# MD        53    17   70         24.285714
# SC        46    14   60         23.333333

# %% [markdown]
# # 3. Analysing the 'Area code' variable

# %%
data.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data['Area code'].nunique()
# Out:
# 3

# %%
data['Area code'].unique()
# Out:
# array([415, 408, 510], dtype=int64)

# %%
data['Area code'].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: Area code, dtype: int64

# %%
data.groupby('Area code')['Churn'].mean().sort_values(ascending=True).head(2).reset_index(name='abc')*100
# Out:
#    Area code        abc
# 0      41500  14.259819
# 1      40800  14.558473

# %%
d=pd.crosstab(data['Area code'],data['Churn'],margins=True)
d['Churn percentage']=d[True]/d['All']*100
print(d)
# Out:
# Churn      False  True   All  Churn percentage
# Area code
# 408          716   122   838         14.558473
# 415         1419   236  1655         14.259819
# 510          715   125   840         14.880952
# All         2850   483  3333         14.491449

# %%
plt.figure(figsize=(20,7))
sns.countplot(data['Area code'],hue=data['Churn'])
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.countplot(x='Area code',hue='Churn',data=data)
# Out:
# <AxesSubplot:xlabel='Area code', ylabel='count'>

# %% [markdown]
# # 4.Analysing the 'Account length' variable

# %%
data['Account length'].unique()
# Out:
# array([128, 107, 137,  84,  75, 118, 121, 147, 141,  74, 168,  95,  62,
#         85,  93,  76,  73,  77, 130, 132, 174,  57,  54,  20, 142, 172,
#         12,  72,  78, 136, 149,  98, 135,  34, 160,  64,  59,  97,  52,
#         60,  96,  87,  81, 125, 116,  38,  40,  43, 113, 126, 150, 138,
#        162,  90,  50,  82, 144,  70,  55, 106,  94, 111,  80, 104,  99,
#        120, 122, 157, 103,  36, 112,  46,  41, 193,  61,  92, 131, 163,
#         91, 127, 110, 117, 140,  83, 145,  56, 151, 139, 115, 146, 185,
#        148,  68, 179,  67,  19, 170, 164,  51,  63,  53, 105,  66,  86,
#         35,  88, 123, 100, 108,  22,  33, 114,  24, 119, 101,  49,  48,
#         71, 167, 166, 158, 196, 209,  16,  39, 173, 129, 143,  89,  44,
#         79,  31,  37, 159, 194, 154,  45,  32,  21, 133,  25, 224,  58,
#        155,  11, 109, 165,  18, 161, 124,  30, 176,  47, 190, 152,  65,
#        186, 171, 102,  28, 153, 169,  13,  42, 189,  69,  27, 134, 156,
# ...

# %%
data['Account length'].nunique()
# Out:
# 212

# %%
data['Account length'].value_counts()
# Out:
# 105    43
# 87     42
# 93     40
# 101    40
# 90     39
#        ..
# 188     1
# 4       1
# 200     1
# 8       1
# 175     1
# Name: Account length, Length: 212, dtype: int64

# %%
churn_data=data[data['Churn']==True]
churn_data.head()
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 18    CO              77        408                 No              No
# 28    AZ              12        408                 No              No
# 35    MD             135        408                Yes             Yes
# 45    WY              87        415                 No              No
# 48    CO             121        408                 No             Yes
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 18                      0               62.4               89
# 28                      0              249.6              118
# 35                     41              173.1               85
# 45                      0              151.0               83
# 48                     30              198.4              129
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 18             10.61              169.9              121             14.44
# ...

# %%
not_churn_data=data[data['Churn']==False]
not_churn_data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
sns.distplot(data['Account length'],color='orange')
plt.show()

# %%
sns.distplot(data['Account length'],color='orange')
sns.distplot(churn_data['Account length'],color='green',hist=False)
sns.distplot(not_churn_data['Account length'],color='blue',hist=False)
plt.figure(figsize=(15,7))

# %%
sns.distplot(data['Account length'],color='orange')
sns.distplot(churn_data['Account length'],color='green',hist=False)
sns.distplot(not_churn_data['Account length'],color='blue',hist=False)
plt.rcParams['figure.figsize']=(15,7)

# %% [markdown]
# # 5.Analysing the 'International plans' variable

# %%
data['International plan'].nunique()
# Out:
# 2

# %%
data['International plan'].value_counts()
# Out:
# No     3010
# Yes     323
# Name: International plan, dtype: int64

# %%
yes_int_plan=data[(data['International plan']=='Yes') & (data['Churn']==True)]
yes_int_plan
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 35      MD             135        408                Yes             Yes
# 93      ME              36        510                Yes             Yes
# 120     VT             117        408                Yes              No
# 162     ME             131        510                Yes             Yes
# 176     FL              70        510                Yes              No
# ...    ...             ...        ...                ...             ...
# 3121    IL              68        415                Yes             Yes
# 3127    NY             126        415                Yes              No
# 3143    WV             152        510                Yes             Yes
# 3161    OR             138        415                Yes             Yes
# 3256    MI             108        408                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
no_int_plan=data[(data['International plan']=='No') & (data['Churn']==True)]
no_int_plan
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 18      CO              77        408                 No              No
# 28      AZ              12        408                 No              No
# 45      WY              87        415                 No              No
# 48      CO             121        408                 No             Yes
# 58      TX             150        510                 No              No
# ...    ...             ...        ...                ...             ...
# 3272    CO             130        408                 No              No
# 3281    MT             100        415                 No              No
# 3318    WA              84        415                 No              No
# 3319    MD             133        510                 No              No
# 3327    CA              84        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
137/323*100
# Out:
# 42.414860681114554

# %%
346/3010*100
# Out:
# 11.495016611295682

# %%
i=pd.crosstab(data['International plan'],data['Churn'],margins=True)
i['churn_percentage']= i[True]/i['All']*100
print(i)
# Out:
# Churn               False  True   All  churn_percentage
# International plan
# No                   2664   346  3010         11.495017
# Yes                   186   137   323         42.414861
# All                  2850   483  3333         14.491449

# %%
i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, No to All
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   False             3 non-null      int64
#  1   True              3 non-null      int64
#  2   All               3 non-null      int64
#  3   churn_percentage  3 non-null      float64
# dtypes: float64(1), int64(3)
# memory usage: 120.0+ bytes

# %%
int1=data['International plan'].value_counts()
int1
# Out:
# No     3010
# Yes     323
# Name: International plan, dtype: int64

# %%
323/3333*100
# Out:
# 9.69096909690969

# %%
3010/3333*100
# Out:
# 90.3090309030903

# %%
plt.figure(figsize=(20,7))
plt.pie(int1,labels=['No_int_plan','Yes_int_plan'],startangle=180,shadow=True,explode=(0,0.1),autopct="%1.2f%%",radius=1.5,pctdistance=0.75)
plt.pie([1],colors='w',radius=0.8)
plt.show()

# %%
sns.countplot(x='International plan',data=data,hue='Churn')
plt.show()

# %% [markdown]
# # 6.Analysing the 'Voice mail plan' column

# %%
data.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data['Voice mail plan'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['Voice mail plan'].nunique()
# Out:
# 2

# %%
data['Voice mail plan'].value_counts()
# Out:
# No     2411
# Yes     922
# Name: Voice mail plan, dtype: int64

# %%
vplan=pd.crosstab(data['Voice mail plan'],data['Churn'],margins=True)
vplan
# Out:
# Churn            False  True   All
# Voice mail plan
# No                2008   403  2411
# Yes                842    80   922
# All               2850   483  3333

# %%
vplan['churn per']=vplan[True]/vplan['All']*100
vplan
# Out:
# Churn            False  True   All  churn per
# Voice mail plan
# No                2008   403  2411  16.715056
# Yes                842    80   922   8.676790
# All               2850   483  3333  14.491449

# %%
#for no voice mail plan
403/2411*100
# Out:
# 16.71505599336375

# %%
#for yes voice mail plan
80/922*100
# Out:
# 8.676789587852495

# %%
v=data['Voice mail plan'].value_counts()

# %%
plt.pie(v,labels=['no','yes'],startangle=90,shadow=True,radius=1.5,explode=(0,0.1),autopct="%1.2f%%",labeldistance=1.1)
plt.pie([1],colors='w',radius=0.8)
plt.show()

# %% [markdown]
# #  7. Analysing the 'Number vmail messages' column

# %%
data['Number vmail messages'].unique()
# Out:
# array([25, 26,  0, 24, 37, 27, 33, 39, 41, 28, 30, 34, 46, 35, 21, 42, 36,
#        22, 23, 43, 31, 38, 40, 29, 18, 32, 17, 45, 16, 14, 20, 19, 15, 12,
#        47,  8, 44,  4, 10, 13, 50,  9, 48, 51, 11, 49], dtype=int64)

# %%
data['Number vmail messages'].nunique()
# Out:
# 46

# %%
data['Number vmail messages'].value_counts()
# Out:
# 0     2411
# 31      60
# 29      53
# 28      51
# 33      46
# 30      44
# 27      44
# 24      42
# 32      41
# 26      41
# 25      37
# 23      36
# 36      34
# 35      32
# 22      32
# 39      30
# 34      29
# 37      29
# 21      28
# 38      25
# 20      22
# 19      19
# 40      16
# 42      15
# 17      14
# 16      13
# 41      13
# 15       9
# 43       9
# 18       7
# 44       7
# 14       7
# 12       6
# 45       6
# 46       4
# 13       4
# 47       3
# 8        2
# 50       2
# 9        2
# 48       2
# 11       2
# 4        1
# 10       1
# 51       1
# 49       1
# Name: Number vmail messages, dtype: int64

# %%
sns.distplot(data['Number vmail messages'])
# Out:
# <AxesSubplot:xlabel='Number vmail messages', ylabel='Density'>

# %%
sns.boxplot(x='Churn',y='Number vmail messages',data=data,color='violet',meanline=True,showmeans=True,sym='r+')
plt.show()

# %% [markdown]
# # 8. Analysing the 'Customer service calls' column

# %%
data.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data['Customer service calls'].unique()
# Out:
# array([1, 0, 2, 3, 4, 5, 7, 9, 6, 8], dtype=int64)

# %%
data['Customer service calls'].nunique()
# Out:
# 10

# %%
data['Customer service calls'].value_counts()
# Out:
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 9       2
# 8       2
# Name: Customer service calls, dtype: int64

# %%
churn_data=data[data['Churn']]
churn_data
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 18      CO              77        408                 No              No
# 28      AZ              12        408                 No              No
# 35      MD             135        408                Yes             Yes
# 45      WY              87        415                 No              No
# 48      CO             121        408                 No             Yes
# ...    ...             ...        ...                ...             ...
# 3272    CO             130        408                 No              No
# 3281    MT             100        415                 No              No
# 3318    WA              84        415                 No              No
# 3319    MD             133        510                 No              No
# 3327    CA              84        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
churn_data['Churn'].unique()
# Out:
# array([ True])

# %%
churn_data1=data[data['Churn']==True]
churn_data1
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 18      CO              77        408                 No              No
# 28      AZ              12        408                 No              No
# 35      MD             135        408                Yes             Yes
# 45      WY              87        415                 No              No
# 48      CO             121        408                 No             Yes
# ...    ...             ...        ...                ...             ...
# 3272    CO             130        408                 No              No
# 3281    MT             100        415                 No              No
# 3318    WA              84        415                 No              No
# 3319    MD             133        510                 No              No
# 3327    CA              84        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
churn_data1['Churn'].unique()
# Out:
# array([ True])

# %%
cscalls=pd.crosstab(data['Customer service calls'],data['Churn'],margins =True)
cscalls['Churn per']=cscalls[True]/cscalls['All']*100
cscalls
# Out:
# Churn                   False  True   All   Churn per
# Customer service calls
# 0                         605    92   697   13.199426
# 1                        1059   122  1181   10.330229
# 2                         672    87   759   11.462451
# 3                         385    44   429   10.256410
# 4                          90    76   166   45.783133
# 5                          26    40    66   60.606061
# 6                           8    14    22   63.636364
# 7                           4     5     9   55.555556
# 8                           1     1     2   50.000000
# 9                           0     2     2  100.000000
# All                      2850   483  3333   14.491449

# %%
sns.countplot('Customer service calls',hue='Churn',color='b',data=data)
plt.show()
# Out:
# C:\Users\pooja\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 9. Analysing the 'per minute charge'

# %%
data.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
dc_pm=data['Total day charge'].mean()/data['Total day minutes'].mean()
dc_pm
# Out:
# 0.1700030073913066

# %%
data['Total day charge'].mean()
# Out:
# 30.56230723072312

# %%
data['Total day minutes'].mean()
# Out:
# 179.77509750975133

# %%
30.56/179.76
# Out:
# 0.17000445037828216

# %%
ec_pm=data['Total eve charge'].mean()/data['Total eve minutes'].mean()
ec_pm
# Out:
# 0.08500104871485784

# %%
nc_pm=data['Total night charge'].mean()/data['Total night minutes'].mean()
nc_pm
# Out:
# 0.04500041448440015

# %%
intc_pm=data['Total intl charge'].mean()/data['Total intl minutes'].mean()
intc_pm
# Out:
# 0.2700500279887102

# %%
sns.barplot(x=['day','eve','night','int'],y=[dc_pm,ec_pm,nc_pm,intc_pm])
plt.show()
